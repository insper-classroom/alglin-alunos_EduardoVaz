# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Geometria Analítica 1

# %% [markdown]
# ### EXERCÍCIO 1

# %%
A = np.array([[2, 2], [5, 2]])
B = np.array([[8], [7]])

np.linalg.solve(A, B)
# Out:
# array([[-0.33333333],
#        [ 4.33333333]])

# %% [markdown]
# ### EXERCÍCIO 3

# %%
A = np.array([[0.40, 0.50, 0.30, 0.60, 0.90, 0.90, 0.60, 0.80, 0.80, 0.60, 1.00, 0.80], [0.90, 0.70, 0.70, 0.60, 0.50, 0.50, 0.10, 0.40, 0.60, 0.30, 0.40, 0.60], [0.10, 0.10, 0.10, 0.50, 0.80, 0.50, 0.20, 0.70, 0.60, 0.70, 0.20, 0.50], [0.90, 0.10, 0.10, 0.10, 0.50, 0.60, 0.20, 0.00, 0.10, 0.10, 0.10, 0.50], [0.90, 0.00, 0.40, 0.60, 0.50, 0.60, 0.70, 0.80, 0.10, 0.10, 0.40, 0.90], [0.80, 0.30, 0.80, 0.60, 0.90, 0.00, 0.80, 0.60, 0.20, 0.80, 0.80, 0.20], [0.40, 0.10, 1.00, 0.10, 1.00, 0.50, 0.10, 0.50, 0.50, 0.20, 0.30, 0.30], [0.30, 0.60, 0.90, 0.20, 0.60, 0.60, 0.80, 0.40, 0.60, 0.90, 0.90, 0.10], [0.90, 0.60, 1.00, 0.20, 0.80, 0.60, 0.30, 0.30, 0.40, 0.00, 0.90, 0.10], [0.10, 0.40, 0.80, 0.30, 0.90, 0.40, 0.50, 0.10, 0.10, 0.50, 0.80, 1.00], [0.20, 0.90, 0.70, 0.20, 0.00, 0.00, 0.70, 0.90, 0.10, 0.20, 0.50, 0.20], [0.60, 0.40, 0.80, 0.90, 0.90, 0.20, 0.40, 0.70, 0.40, 0.20, 0.10, 0.60]])

np.linalg.inv(A)
# Out:
# array([[ 0.36411214,  0.61483876, -0.74850095,  0.66550327, -0.11649485,
#          0.76288648,  0.50431998, -0.37008952, -0.57428955, -0.46764133,
#          0.05304932, -0.44375446],
#        [-0.32592091, -0.22167271,  0.80600406,  0.85121744, -0.94133378,
#         -0.43074062, -0.90083798, -0.18885   ,  0.6975705 ,  0.28190015,
#          0.86489297,  0.43829789],
#        [-1.10839163,  0.4875845 ,  0.1794975 , -0.90695507,  0.74741832,
#         -0.37209913,  0.27954146,  0.63507325,  0.231163  ,  0.30187854,
#         -0.25569378, -0.10265187],
#        [-1.5767215 , -0.00906297,  1.88363435, -1.44364944,  1.03514138,
#         -0.73672606, -2.17737362,  0.59754565,  1.92481712,  0.3296067 ,
#         -0.8848764 ,  0.85147482],
#        [ 0.45292239, -1.12986811,  0.18766092,  0.98606985, -1.036321  ,
#          0.26834743,  0.14900473, -0.61098993,  0.32385124,  0.12447347,
#          0.21214594,  0.70807796],
# ...

# %% [markdown]
# ## Geometria Analítica 2
